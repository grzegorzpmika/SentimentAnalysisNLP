# %% [markdown]
# ### Import libraries

# %%
# -*- coding: utf-8 -*-
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import re

# %% [markdown]
# ### Load raw file

# %%
with open('rev_sentence.txt', 'r') as f:
    sentences = f.readlines()
    
print(len(sentences))
sentences = [re.sub('[^\w0-9\s]+', '', sentence) for sentence in x]
sentences
# Out:
# 965
# ['Słodkawy i pełen klasy  \n',
#  'Letnia propozycja dla wysmakowanych mężczyzn  \n',
#  'Raczej nie dla młodych chłopców  \n',
#  'Ciekawa kolorystyka flakonu  który mieści 200 ml wody  \n',
#  'Nie pasuje do chłopaka  luzaka  \n',
#  'Poza tym wyczuć można mocną świeżość  \n',
#  'Zapach godny pozazdroszczenia  \n',
#  'Gdy przechodzi opbok mnie czuję zdecydowaną woń limonki  cytrusów  \n',
#  'Gucci Rush można dać jako prezent bliskiej osobie  \n',
#  'Mam pojemność 100ml  flakon bardzo ciężki  tylko do stacjonarnego używania  \n',
#  'Ciekawy i niemęczący zapach  \n',
#  'Bardzo fajny desing butelki  \n',
#  'Dla prawdziwego faceta  \n',
#  'Połączenie stylu i elegancji  \n',
#  'Chanel Coco Mademoisella to raczej zapach bardzo zdecydowany  \n',
#  'Nie drażni nawet po całym dniu  \n',
#  'Redukuje przykrą woń  \n',
#  'Zapach jak by uniwersalny a za razem w jakiś sposób magiczny  \n',
#  'Wyrazisty  z odrobiną słodyczy  \n',
#  'Świetna butelka i opakowanie  \n',
# ...

# %% [markdown]
# ### Lowercase process

# %%
sentences_lowercase = [sentence.lower() for sentence in sentences]
sentences_lowercase
# Out:
# ['słodkawy i pełen klasy  \n',
#  'letnia propozycja dla wysmakowanych mężczyzn  \n',
#  'raczej nie dla młodych chłopców  \n',
#  'ciekawa kolorystyka flakonu  który mieści 200 ml wody  \n',
#  'nie pasuje do chłopaka  luzaka  \n',
#  'poza tym wyczuć można mocną świeżość  \n',
#  'zapach godny pozazdroszczenia  \n',
#  'gdy przechodzi opbok mnie czuję zdecydowaną woń limonki  cytrusów  \n',
#  'gucci rush można dać jako prezent bliskiej osobie  \n',
#  'mam pojemność 100ml  flakon bardzo ciężki  tylko do stacjonarnego używania  \n',
#  'ciekawy i niemęczący zapach  \n',
#  'bardzo fajny desing butelki  \n',
#  'dla prawdziwego faceta  \n',
#  'połączenie stylu i elegancji  \n',
#  'chanel coco mademoisella to raczej zapach bardzo zdecydowany  \n',
#  'nie drażni nawet po całym dniu  \n',
#  'redukuje przykrą woń  \n',
#  'zapach jak by uniwersalny a za razem w jakiś sposób magiczny  \n',
#  'wyrazisty  z odrobiną słodyczy  \n',
#  'świetna butelka i opakowanie  \n',
# ...

# %% [markdown]
# ### Tokenize process

# %%
sentences_tokens_list = [word_tokenize(sentence) for sentence in sentences_lowercase]
sentences_tokens_list
# Out:
# [['słodkawy', 'i', 'pełen', 'klasy'],
#  ['letnia', 'propozycja', 'dla', 'wysmakowanych', 'mężczyzn'],
#  ['raczej', 'nie', 'dla', 'młodych', 'chłopców'],
#  ['ciekawa', 'kolorystyka', 'flakonu', 'który', 'mieści', '200', 'ml', 'wody'],
#  ['nie', 'pasuje', 'do', 'chłopaka', 'luzaka'],
#  ['poza', 'tym', 'wyczuć', 'można', 'mocną', 'świeżość'],
#  ['zapach', 'godny', 'pozazdroszczenia'],
#  ['gdy',
#   'przechodzi',
#   'opbok',
#   'mnie',
#   'czuję',
#   'zdecydowaną',
#   'woń',
#   'limonki',
#   'cytrusów'],
#  ['gucci', 'rush', 'można', 'dać', 'jako', 'prezent', 'bliskiej', 'osobie'],
#  ['mam',
#   'pojemność',
#   '100ml',
#   'flakon',
#   'bardzo',
#   'ciężki',
#   'tylko',
#   'do',
#   'stacjonarnego',
#   'używania'],
#  ['ciekawy', 'i', 'niemęczący', 'zapach'],
#  ['bardzo', 'fajny', 'desing', 'butelki'],
#  ['dla', 'prawdziwego', 'faceta'],
#  ['połączenie', 'stylu', 'i', 'elegancji'],
#  ['chanel',
#   'coco',
#   'mademoisella',
#   'to',
#   'raczej',
# ...

# %% [markdown]
# ### Stem process

# %%
#ps = PorterStemmer()

#sentences_stem = []

#for sentence in sentences_tokens_list:
#    sentences_stem.append([ps.stem(word) for word in sentence])
#sentences_stem

# %% [markdown]
# ### Lemmitize process

# %%
#lemmatizer = WordNetLemmatizer()
#
#sentences_lemmatize = []
#
#for sentence in sentences_tokens_list:
#    sentences_lemmatize.append([lemmatizer.lemmatize(word) for word in sentence])
#sentences_lemmatize

# %% [markdown]
# ### Embeddings train

# %%
words_embeddings_model = Word2Vec(sentences_tokens_list)

# %% [markdown]
# ### Save embeddings model

# %%
words_embeddings_model.save('/tmp/mymodel')

# %% [markdown]
# ### Load embeddings model

# %%
new_model = Word2Vec.load('/tmp/mymodel')

# %% [markdown]
# ### Embeddings model evaluation

# %%
new_model.similarity('zapach','zapach')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 1.0
